# %% [markdown]
# Welcome to Covid19 Data Analysis Notebook

# %% [markdown]
# Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
confirmed_df=pd.read_csv('covid19_confirmed_dataset.csv')
deaths_df=pd.read_csv('covid19_deaths_dataset.csv')

# %%
confirmed_df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
deaths_df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %% [markdown]
# let's check the shape of the dataframel

# %%
confirmed_df.shape
# Out:
# (266, 104)

# %%
deaths_df.shape
# Out:
# (266, 104)

# %% [markdown]
# Delete the useless columns

# %%
confirmed_df=pd.read_csv("covid19_Confirmed_dataset.csv")
confirmed_df=confirmed_df.drop(columns=['Lat','Long','Province/State'])
deaths_df=pd.read_csv('covid19_deaths_dataset.csv')
deaths_df=deaths_df.drop(columns=['Lat','Long','Province/State'])

# %%
confirmed_df.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0     1463     1531     1703     1828     1939     2171
# ...

# %%
deaths_df.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0       47       50       57       58       60       64
# ...

# %% [markdown]
# Aggregating the rows by the country

# %%
confirmed_df=confirmed_df.groupby(by='Country/Region').aggregate(np.sum).T
deaths_df=deaths_df.groupby(by='Country/Region').aggregate(np.sum).T

# %%
confirmed_df
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
# ...                     ...      ...      ...      ...     ...
# 4/26/20                1531      726     3382      738      26
# 4/27/20                1703      736     3517      743      27
# 4/28/20                1828      750     3649      743      27
# 4/29/20                1939      766     3848      743      27
# 4/30/20                2171      773     4006      745      27
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# ...

# %%
deaths_df
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
# ...                     ...      ...      ...      ...     ...
# 4/26/20                  50       28      425       40       2
# 4/27/20                  57       28      432       40       2
# 4/28/20                  58       30      437       41       2
# 4/29/20                  60       30      444       42       2
# 4/30/20                  64       31      450       42       2
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# ...

# %%
confirmed_df.index.name='Date'
confirmed_df=confirmed_df.reset_index()
deaths_df.index.name='Date'
deaths_df=deaths_df.reset_index()

# %%
confirmed_df.tail()
# Out:
# Country/Region     Date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 95              4/26/20         1531      726     3382      738      26
# 96              4/27/20         1703      736     3517      743      27
# 97              4/28/20         1828      750     3649      743      27
# 98              4/29/20         1939      766     3848      743      27
# 99              4/30/20         2171      773     4006      745      27
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  ...  \
# 95                               24       3892     1746       6714  ...
# 96                               24       4003     1808       6721  ...
# 97                               24       4127     1867       6744  ...
# 98                               24       4285     1932       6752  ...
# 99                               24       4428     2066       6766  ...
#
# Country/Region  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
deaths_df.tail()
# Out:
# Country/Region     Date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 95              4/26/20           50       28      425       40       2
# 96              4/27/20           57       28      432       40       2
# 97              4/28/20           58       30      437       41       2
# 98              4/29/20           60       30      444       42       2
# 99              4/30/20           64       31      450       42       2
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  ...  \
# 95                                3        192       28         83  ...
# 96                                3        197       29         83  ...
# 97                                3        207       30         89  ...
# 98                                3        214       30         91  ...
# 99                                3        218       32         93  ...
#
# Country/Region  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
confirmed_melt_df=confirmed_df.melt(id_vars='Date').copy()
deaths_melt_df=deaths_df.melt(id_vars='Date').copy()

# %%
confirmed_melt_df
# Out:
#           Date Country/Region  value
# 0      1/22/20    Afghanistan      0
# 1      1/23/20    Afghanistan      0
# 2      1/24/20    Afghanistan      0
# 3      1/25/20    Afghanistan      0
# 4      1/26/20    Afghanistan      0
# ...        ...            ...    ...
# 18695  4/26/20       Zimbabwe     31
# 18696  4/27/20       Zimbabwe     32
# 18697  4/28/20       Zimbabwe     32
# 18698  4/29/20       Zimbabwe     32
# 18699  4/30/20       Zimbabwe     40
#
# [18700 rows x 3 columns]

# %%
deaths_melt_df
# Out:
#           Date Country/Region  value
# 0      1/22/20    Afghanistan      0
# 1      1/23/20    Afghanistan      0
# 2      1/24/20    Afghanistan      0
# 3      1/25/20    Afghanistan      0
# 4      1/26/20    Afghanistan      0
# ...        ...            ...    ...
# 18695  4/26/20       Zimbabwe      4
# 18696  4/27/20       Zimbabwe      4
# 18697  4/28/20       Zimbabwe      4
# 18698  4/29/20       Zimbabwe      4
# 18699  4/30/20       Zimbabwe      4
#
# [18700 rows x 3 columns]

# %%
confirmed_melt_df.rename(columns={'value':'confirmed'},inplace=True)
deaths_melt_df.rename(columns={'value':'death'},inplace=True)

# %%
confirmed_melt_df.head(5)
# Out:
#       Date Country/Region  confirmed
# 0  1/22/20    Afghanistan          0
# 1  1/23/20    Afghanistan          0
# 2  1/24/20    Afghanistan          0
# 3  1/25/20    Afghanistan          0
# 4  1/26/20    Afghanistan          0

# %%
deaths_melt_df.head(5)
# Out:
#       Date Country/Region  death
# 0  1/22/20    Afghanistan      0
# 1  1/23/20    Afghanistan      0
# 2  1/24/20    Afghanistan      0
# 3  1/25/20    Afghanistan      0
# 4  1/26/20    Afghanistan      0

# %%
max_date=confirmed_melt_df['Date'].max()
max_date
# Out:
# '4/9/20'

# %%
max_date=deaths_melt_df['Date'].max()
max_date
# Out:
# '4/9/20'

# %% [markdown]
# Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
total_confirmed_df=confirmed_melt_df[confirmed_melt_df['Date']==max_date]
total_deaths_df=deaths_melt_df[deaths_melt_df['Date']==max_date]

# %%
total_deaths_df
# Out:
#          Date      Country/Region  death
# 78     4/9/20         Afghanistan     15
# 178    4/9/20             Albania     23
# 278    4/9/20             Algeria    235
# 378    4/9/20             Andorra     25
# 478    4/9/20              Angola      2
# ...       ...                 ...    ...
# 18278  4/9/20  West Bank and Gaza      1
# 18378  4/9/20      Western Sahara      0
# 18478  4/9/20               Yemen      0
# 18578  4/9/20              Zambia      1
# 18678  4/9/20            Zimbabwe      3
#
# [187 rows x 3 columns]

# %%
total_confirmed_df
# Out:
#          Date      Country/Region  confirmed
# 78     4/9/20         Afghanistan        484
# 178    4/9/20             Albania        409
# 278    4/9/20             Algeria       1666
# 378    4/9/20             Andorra        583
# 478    4/9/20              Angola         19
# ...       ...                 ...        ...
# 18278  4/9/20  West Bank and Gaza        263
# 18378  4/9/20      Western Sahara          4
# 18478  4/9/20               Yemen          0
# 18578  4/9/20              Zambia         39
# 18678  4/9/20            Zimbabwe         11
#
# [187 rows x 3 columns]

# %%
total_confirmed=total_confirmed_df['confirmed'].sum()
total_deaths=total_deaths_df['death'].sum()

# %%
total_deaths
# Out:
# 100882

# %%
total_confirmed
# Out:
# 1565538

# %%
pd.set_option('mode.chained_assignment',None)
fig=px.choropleth(total_confirmed_df,locations='Country/Region',locationmode='country names',color_continuous_scale='dense',color=total_confirmed_df['confirmed'],
range_color=(0,10)
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-606de9221500> in <module>
#       1 pd.set_option('mode.chained_assignment',None)
# ----> 2 fig=px.choropleth(total_confirmed_df,locations='Country/Region',locationmode='country names',color_continuous_scale='dense',color=total_confirmed_df['confirmed'],
#       3 range_color=(0,10)
#       4 )
#       5 fig.show()
#
# NameError: name 'total_confirmed_df' is not defined

# %%
import plotly.express as px
fig=px.bar(total_confirmed_df, x='Country/Region',y='confirmed')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b54f2737d845> in <module>
#       1 import plotly.express as px
# ----> 2 fig=px.bar(total_confirmed_df, x='Country/Region',y='confirmed')
#       3 fig.show()
#
# NameError: name 'total_confirmed_df' is not defined

# %%
fig=px.bar(total_confirmed_df.sort_values('confirmed',ascending=False).head(30),x='Country/Region',y='confirmed',text='confirmed')
fig.show()

# %%
fig2=px.scatter(confirmed_melt_df,x='Date',y='confirmed',color='Country/Region')
fig2.show()

# %%
import matplotlib.animation as animation
from IPython.display import HTML
fig,ax=plt.subplots(figsize=(15,8))
animator=animation.FuncAnimation(fig,fig2,frames=confirmed_melt_df)
HTML(animator.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-249-4e3022c83d05> in <module>
#       3 fig,ax=plt.subplots(figsize=(15,8))
#       4 animator=animation.FuncAnimation(fig,fig2,frames=confirmed_melt_df)
# ----> 5 HTML(animator.to_jshtml())
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\animation.py in to_jshtml(self, fps, embed_frames, default_mode)
#    1400                                     embed_frames=embed_frames,
#    1401                                     default_mode=default_mode)
# -> 1402                 self.save(str(path), writer=writer)
#    1403                 self._html_representation = path.read_text()
#    1404
#
# ...

# %%
fig3=px.line(confirmed_melt_df[confirmed_melt_df['Country/Region']=='China'],x='Date',y='confirmed')
fig3.show()

# %%
fig4=px.line(confirmed_melt_df[confirmed_melt_df['Country/Region']=='India'],x='Date',y='confirmed')
fig4.show()

# %%
confirmed_melt_df.loc['China'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-bdd6a3a2676b> in <module>
# ----> 1 confirmed_melt_df.loc['China'].plot()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ...

# %%
new_df=confirmed_melt_df.drop(columns=['Date'])

# %%
new_df
# Out:
#       Country/Region  confirmed
# 0        Afghanistan          0
# 1        Afghanistan          0
# 2        Afghanistan          0
# 3        Afghanistan          0
# 4        Afghanistan          0
# ...              ...        ...
# 18695       Zimbabwe         31
# 18696       Zimbabwe         32
# 18697       Zimbabwe         32
# 18698       Zimbabwe         32
# 18699       Zimbabwe         40
#
# [18700 rows x 2 columns]

# %%
A=total_confirmed_df.copy()
A['death']=total_deaths_df['death']
A['infection rate']=(A['death']/A['confirmed']*100).round(2)
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-31c6ab9696c6> in <module>
# ----> 1 A=total_confirmed_df.copy()
#       2 A['death']=total_deaths_df['death']
#       3 A['infection rate']=(A['death']/A['confirmed']*100).round(2)
#       4 A
#
# NameError: name 'total_confirmed_df' is not defined

# %%
max_infection_rate=deaths_melt_df['Date'].max()
max_date
# Out:
# '4/9/20'

# %%
fig=px.scatter(
    A,
    x='confirmed',y='death',
    color='red',
    
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3c137b94b969> in <module>
#       1 fig=px.scatter(
# ----> 2     A,
#       3     x='confirmed',y='death',
#       4     color='red',
#       5
#
# NameError: name 'A' is not defined

# %%
B=A.copy()
B=B.sort_values(by='death',ascending=False).head(20)
B
# Out:
#          Date  Country/Region  confirmed  death  infection rate
# 17378  4/9/20              US     462780  20255            4.38
# 8578   4/9/20           Italy     143626  18279           12.73
# 15778  4/9/20           Spain     153222  15447           10.08
# 6278   4/9/20          France      87366  12228           14.00
# 17778  4/9/20  United Kingdom      65872   9623           14.61
# 8178   4/9/20            Iran      66220   4110            6.21
# 3678   4/9/20           China      82883   3339            4.03
# 6678   4/9/20         Germany     118181   2607            2.21
# 1678   4/9/20         Belgium      24983   2523           10.10
# 12178  4/9/20     Netherlands      21903   2403           10.97
# 2378   4/9/20          Brazil      18092    950            5.25
# 16278  4/9/20     Switzerland      24051    948            3.94
# 17278  4/9/20          Turkey      42282    908            2.15
# 16178  4/9/20          Sweden       9141    793            8.68
# ...

# %%
c=confirmed_melt_df.groupby(by='Date').aggregate(np.sum)
c.index.name='Date'
c=c.reset_index()
c['Dailyconfirmed']=c['confirmed'].diff()
c
# Out:
#        Date  confirmed  Dailyconfirmed
# 0   1/22/20        555             NaN
# 1   1/23/20        654            99.0
# 2   1/24/20        941           287.0
# 3   1/25/20       1434           493.0
# 4   1/26/20       2118           684.0
# ..      ...        ...             ...
# 95   4/5/20    1249737         73678.0
# 96   4/6/20    1321427         71690.0
# 97   4/7/20    1396438         75011.0
# 98   4/8/20    1480200         83762.0
# 99   4/9/20    1565538         85338.0
#
# [100 rows x 3 columns]

# %%
fig=px.area(c,x='Date',y='Dailyconfirmed')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-09ac06b06454> in <module>
# ----> 1 fig=px.area(c,x='Date',y='Dailyconfirmed')
#       2 fig.show()
#
# NameError: name 'c' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-152-389588cb75c1> in <module>
#       5 bs4=BeautifulSoup(r.content,'html')
#       6 table=bs4.find_all('table')[0]
# ----> 7 population_df=pd.read_html(str(table))[0]
#       8 population_df=population_df.rename(columns={"Country (or dependancy)":"Country/Region","Population(2020)":"Population"})
#       9 population_df.replace("United States","US",inplace=True)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %% [markdown]
# Importing the WorldHappinessReport.csv dataset
# selecting needed columns for our analysis
# join the datasets
# calculate the correlations as the result of our analysis

# %%
happiness_df=pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
happiness_df=pd.read_csv("worldwide_happiness_report.csv")
happiness_df=happiness_df.drop(columns=['Score','Generosity','Perceptions of corruption'])

# %%
happiness_df
# Out:
#      Overall rank         Country or region  GDP per capita  Social support  \
# 0               1                   Finland           1.340           1.587
# 1               2                   Denmark           1.383           1.573
# 2               3                    Norway           1.488           1.582
# 3               4                   Iceland           1.380           1.624
# 4               5               Netherlands           1.396           1.522
# ..            ...                       ...             ...             ...
# 151           152                    Rwanda           0.359           0.711
# 152           153                  Tanzania           0.476           0.885
# 153           154               Afghanistan           0.350           0.517
# 154           155  Central African Republic           0.026           0.000
# 155           156               South Sudan           0.306           0.575
#
# ...

# %%
fig6=px.line(happiness_df[happiness_df['Country or region']=='India'],x='GDP per capita',y='Healthy life expectancy')
fig6.show()

# %%
happiness_df=happiness_df.set_index("",inplace=True)
happiness_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4a2ff2ca2e5d> in <module>
# ----> 1 happiness_df=happiness_df.set_index("",inplace=True)
#       2 happiness_df
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of [''] are in the columns"

# %% [markdown]
# join two data sets

# %%
import pandas as pd
df_row_reindex = pd.concat([A, happiness_df], ignore_index=True)
df_row_reindex
# Out:
#        Date Country/Region  confirmed  death  infection rate  Overall rank  \
# 0    4/9/20    Afghanistan      484.0   15.0            3.10           NaN
# 1    4/9/20        Albania      409.0   23.0            5.62           NaN
# 2    4/9/20        Algeria     1666.0  235.0           14.11           NaN
# 3    4/9/20        Andorra      583.0   25.0            4.29           NaN
# 4    4/9/20         Angola       19.0    2.0           10.53           NaN
# ..      ...            ...        ...    ...             ...           ...
# 338     NaN            NaN        NaN    NaN             NaN         152.0
# 339     NaN            NaN        NaN    NaN             NaN         153.0
# 340     NaN            NaN        NaN    NaN             NaN         154.0
# 341     NaN            NaN        NaN    NaN             NaN         155.0
# 342     NaN            NaN        NaN    NaN             NaN         156.0
#
#             Country or region  GDP per capita  Social support  \
# ...

# %%
corrmatrix=df_row_reindex.corr()
corrmatrix
# Out:
#                               confirmed     death  infection rate  \
# confirmed                      1.000000  0.870096        0.104698
# death                          0.870096  1.000000        0.223926
# infection rate                 0.104698  0.223926        1.000000
# Overall rank                        NaN       NaN             NaN
# GDP per capita                      NaN       NaN             NaN
# Social support                      NaN       NaN             NaN
# Healthy life expectancy             NaN       NaN             NaN
# Freedom to make life choices        NaN       NaN             NaN
#
#                               Overall rank  GDP per capita  Social support  \
# confirmed                              NaN             NaN             NaN
# death                                  NaN             NaN             NaN
# infection rate                         NaN             NaN             NaN
# ...

# %%
plt.xlabel('infectionrate')
plt.ylabel('Social support')
plt.scatter(infectionrate,Social support,color='green')
plt.show()
# Out:
#   File "<ipython-input-9-b2ed98e2817d>", line 3
#     plt.scatter(infectionrate,Social support,color='green')
#                                      ^
# SyntaxError: invalid syntax
